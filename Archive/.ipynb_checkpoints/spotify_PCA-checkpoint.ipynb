# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in data
data = Path("Resources/spotify_music_target.csv")
df = pd.read_csv(data)
df.head()
# Out:
#    Unnamed: 0         artist                                track  \
# 0           0       SUPER-Hi                    Following the Sun
# 1           1          Latto                           Big Energy
# 2           2          Lizzo                      About Damn Time
# 3           3  The Kid LAROI                       Thousand Miles
# 4           4  Calvin Harris  Potion (with Dua Lipa & Young Thug)
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  ...  \
# 0         0.734   0.828    6    -4.433     0       0.0330        0.3980  ...
# 1         0.935   0.807   11    -3.838     0       0.1140        0.0514  ...
# 2         0.836   0.743   10    -6.305     0       0.0656        0.0995  ...
# 3         0.376   0.657    7    -4.658     1       0.0768        0.0858  ...
# 4         0.824   0.697   11    -4.869     0       0.0473        0.1580  ...
#
#    valence    tempo            type                      id  \
# 0    0.717  127.023  audio_features  2sFbdDiEDpyCdP5nUCuGBm
# 1    0.813  106.017  audio_features  6Zu3aw7FfjAF9WA0fA81Oq
# 2    0.722  108.966  audio_features  1PckUlxKqWQs3RlWXVBLw3
# 3    0.203   80.565  audio_features  1r8ZCjfrQxoy2wVaBUbpwg
# 4    0.757   99.988  audio_features  7fYRg3CEbk6rNCuzNzMT06
#
#                                     uri  \
# 0  spotify:track:2sFbdDiEDpyCdP5nUCuGBm
# 1  spotify:track:6Zu3aw7FfjAF9WA0fA81Oq
# 2  spotify:track:1PckUlxKqWQs3RlWXVBLw3
# 3  spotify:track:1r8ZCjfrQxoy2wVaBUbpwg
# 4  spotify:track:7fYRg3CEbk6rNCuzNzMT06
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2sFbdDiEDpyC...
# 1  https://api.spotify.com/v1/tracks/6Zu3aw7FfjAF...
# 2  https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
# 3  https://api.spotify.com/v1/tracks/1r8ZCjfrQxoy...
# 4  https://api.spotify.com/v1/tracks/7fYRg3CEbk6r...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2sFb...      205000
# 1  https://api.spotify.com/v1/audio-analysis/6Zu3...      173182
# 2  https://api.spotify.com/v1/audio-analysis/1Pck...      191822
# 3  https://api.spotify.com/v1/audio-analysis/1r8Z...      164782
# 4  https://api.spotify.com/v1/audio-analysis/7fYR...      214460
#
#   time_signature  target
# 0              4       1
# 1              4       1
# 2              4       1
# 3              4       0
# 4              4       0
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'track', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature', 'target'],
#       dtype='object')

# %%
raw_data = df.drop(['Unnamed: 0',"artist","track","type","id","uri","track_href","analysis_url","time_signature"],axis=1)
raw_data.head(20)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.734   0.828    6    -4.433     0       0.0330       0.39800
# 1          0.935   0.807   11    -3.838     0       0.1140       0.05140
# 2          0.836   0.743   10    -6.305     0       0.0656       0.09950
# 3          0.376   0.657    7    -4.658     1       0.0768       0.08580
# 4          0.824   0.697   11    -4.869     0       0.0473       0.15800
# 5          0.520   0.731    6    -5.338     0       0.0557       0.34200
# 6          0.671   0.636    6    -8.117     0       0.1030       0.51500
# 7          0.905   0.563    8    -6.135     1       0.1020       0.02540
# 8          0.552   0.873    0    -6.065     1       0.0464       0.00137
# 9          0.669   0.773    0    -5.619     1       0.1530       0.03800
# 10         0.714   0.728   10    -4.595     1       0.0468       0.29800
# 11         0.478   0.822    2    -1.961     0       0.0642       0.10100
# 12         0.712   0.861    5    -5.487     0       0.2500       0.01820
# 13         0.575   0.556    4    -5.107     1       0.0283       0.03030
# 14         0.790   0.670    1    -5.527     1       0.1050       0.37700
# 15         0.764   0.705    3    -5.279     0       0.0278       0.03710
# 16         0.680   0.428    6    -8.107     0       0.1350       0.37600
# 17         0.370   0.559    0    -5.589     1       0.0526       0.18600
# 18         0.544   0.786    8    -2.970     1       0.0501       0.00991
# 19         0.872   0.696    2    -6.898     1       0.2680       0.09180
#
#     instrumentalness  liveness  valence    tempo  duration_ms  target
# 0           0.022500    0.1360    0.717  127.023       205000       1
# 1           0.000000    0.3490    0.813  106.017       173182       1
# 2           0.000000    0.3350    0.722  108.966       191822       1
# 3           0.000000    0.0884    0.203   80.565       164782       0
# 4           0.000041    0.0770    0.757   99.988       214460       0
# 5           0.001010    0.3110    0.662  173.930       167303       0
# 6           0.000411    0.1720    0.262  120.966       148197       1
# 7           0.000010    0.1130    0.324  106.998       173948       0
# 8           0.000273    0.0966    0.620  125.059       227240       1
# 9           0.000000    0.1130    0.377   93.923       185857       0
# 10          0.000000    0.1060    0.901  114.996       177955       1
# 11          0.000066    0.1200    0.309  130.058       232959       1
# 12          0.000006    0.5110    0.388   84.042       148571       0
# 13          0.000000    0.0903    0.440   87.991       177879       0
# 14          0.000002    0.1190    0.408  139.956       195950       0
# 15          0.000019    0.0943    0.672  101.003       196520       0
# 16          0.000344    0.3550    0.334   98.222       269333       0
# 17          0.000000    0.1210    0.316  162.816       180274       0
# 18          0.000000    0.1690    0.446  153.967       157138       1
# 19          0.000000    0.1640    0.758  135.087       188111       1

# %%
# Define the features X set and the target y vector
X = raw_data.drop("target",axis=1).values
y = raw_data["target"].values

# %%
# Scale the data of the features set using the StandardScaler
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %%
# Define the model - shallow neural network
nn = Sequential()

# Hidden layer
nn.add(Dense(units=8, input_dim=12, activation="relu"))

# Output layer
nn.add(Dense(units=1, activation="linear"))

# %%
# Compile the model
nn.compile(loss="mean_squared_error", optimizer="adam", metrics=["accuracy"])

# Fit the model
model = nn.fit(X, y, epochs=300,verbose=0)

# %%
# Save model as JSON
nn_json = nn.to_json()

file_path = Path("Resources/model.json")
with open(file_path, "w") as json_file:
    json_file.write(nn_json)

# Save weights
file_path = "Resources/model.h5"
nn.save_weights("Resources/model.h5")

# %%
# Load the saved model to make predictions
from tensorflow.keras.models import model_from_json

# load json and create model
file_path = Path("Resources/model.json")
with open(file_path, "r") as json_file:
    model_json = json_file.read()
loaded_model = model_from_json(model_json)

# load weights into new model
file_path = "Resources/model.h5"
loaded_model.load_weights(file_path)

# %%
# Plot the train function
import matplotlib.pyplot as plt

# %matplotlib inline

plt.plot(model.history["loss"])
plt.title("loss_function - training")
plt.legend(["loss"])
plt.show()

# %%
# Make some predictions with the loaded model
raw_data["predicted"] = loaded_model.predict(X)
raw_data.head(30)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.734   0.828    6    -4.433     0       0.0330      0.398000
# 1          0.935   0.807   11    -3.838     0       0.1140      0.051400
# 2          0.836   0.743   10    -6.305     0       0.0656      0.099500
# 3          0.376   0.657    7    -4.658     1       0.0768      0.085800
# 4          0.824   0.697   11    -4.869     0       0.0473      0.158000
# 5          0.520   0.731    6    -5.338     0       0.0557      0.342000
# 6          0.671   0.636    6    -8.117     0       0.1030      0.515000
# 7          0.905   0.563    8    -6.135     1       0.1020      0.025400
# 8          0.552   0.873    0    -6.065     1       0.0464      0.001370
# 9          0.669   0.773    0    -5.619     1       0.1530      0.038000
# 10         0.714   0.728   10    -4.595     1       0.0468      0.298000
# 11         0.478   0.822    2    -1.961     0       0.0642      0.101000
# 12         0.712   0.861    5    -5.487     0       0.2500      0.018200
# 13         0.575   0.556    4    -5.107     1       0.0283      0.030300
# 14         0.790   0.670    1    -5.527     1       0.1050      0.377000
# 15         0.764   0.705    3    -5.279     0       0.0278      0.037100
# 16         0.680   0.428    6    -8.107     0       0.1350      0.376000
# 17         0.370   0.559    0    -5.589     1       0.0526      0.186000
# 18         0.544   0.786    8    -2.970     1       0.0501      0.009910
# 19         0.872   0.696    2    -6.898     1       0.2680      0.091800
# 20         0.657   0.882    9    -5.507     0       0.1590      0.000641
# 21         0.799   0.653    2    -5.453     0       0.0370      0.019000
# 22         0.833   0.652   11    -6.942     1       0.0762      0.001610
# 23         0.308   0.861   11    -4.112     0       0.1720      0.012000
# 24         0.824   0.764    5    -4.175     0       0.0854      0.088800
# 25         0.817   0.775   10    -4.767     0       0.1080      0.277000
# 26         0.614   0.644    2    -5.372     0       0.0426      0.013400
# 27         0.815   0.848    4    -4.704     0       0.1150      0.023000
# 28         0.814   0.628    7    -7.178     1       0.2210      0.167000
# 29         0.737   0.846    1    -4.510     0       0.2200      0.006140
#
#     instrumentalness  liveness  valence    tempo  duration_ms  target  \
# 0           0.022500    0.1360   0.7170  127.023       205000       1
# 1           0.000000    0.3490   0.8130  106.017       173182       1
# 2           0.000000    0.3350   0.7220  108.966       191822       1
# 3           0.000000    0.0884   0.2030   80.565       164782       0
# 4           0.000041    0.0770   0.7570   99.988       214460       0
# 5           0.001010    0.3110   0.6620  173.930       167303       0
# 6           0.000411    0.1720   0.2620  120.966       148197       1
# 7           0.000010    0.1130   0.3240  106.998       173948       0
# 8           0.000273    0.0966   0.6200  125.059       227240       1
# 9           0.000000    0.1130   0.3770   93.923       185857       0
# 10          0.000000    0.1060   0.9010  114.996       177955       1
# 11          0.000066    0.1200   0.3090  130.058       232959       1
# 12          0.000006    0.5110   0.3880   84.042       148571       0
# 13          0.000000    0.0903   0.4400   87.991       177879       0
# 14          0.000002    0.1190   0.4080  139.956       195950       0
# 15          0.000019    0.0943   0.6720  101.003       196520       0
# 16          0.000344    0.3550   0.3340   98.222       269333       0
# 17          0.000000    0.1210   0.3160  162.816       180274       0
# 18          0.000000    0.1690   0.4460  153.967       157138       1
# 19          0.000000    0.1640   0.7580  135.087       188111       1
# 20          0.001020    0.0623   0.5120  132.077       174545       1
# 21          0.000000    0.0935   0.2360  104.019       215281       0
# 22          0.098500    0.1060   0.4050  158.022       135053       0
# 23          0.001030    0.2770   0.0386  171.966       158774       1
# 24          0.002940    0.1170   0.8810  107.998       172627       1
# 25          0.000000    0.1080   0.8060  126.984       234334       0
# 26          0.000007    0.1170   0.6510  160.036       206772       1
# 27          0.000162    0.0265   0.6840  106.032       133707       1
# 28          0.000000    0.1010   0.6770  123.977       201334       1
# 29          0.000000    0.0486   0.5460   87.981       143901       0
#
#     predicted
# 0    1.002298
# 1    1.006398
# 2    0.991540
# 3   -0.001926
# 4   -0.005701
# 5   -0.000324
# 6    0.999176
# 7   -0.000845
# 8    0.995148
# 9    0.004213
# 10   0.998831
# 11   1.001568
# 12  -0.000113
# 13  -0.000328
# 14  -0.002855
# 15   0.075558
# 16   0.002185
# 17  -0.003838
# 18   1.001157
# 19   1.002796
# 20   1.000567
# 21   0.000769
# 22   0.007431
# 23   1.001125
# 24   0.962688
# 25  -0.002541
# 26   1.003358
# 27   1.027687
# 28   0.998163
# 29  -0.001369

# %%
# Evaluate the model with the MSE metric
model_loss, model_accuracy = nn.evaluate(X, y, verbose=2)

print(f"Loss: {round(model_loss,4)} \nAccuracy: {round((model_accuracy*100),4)}%")
# Out:
# 2/2 - 0s - loss: 1.9287e-04 - accuracy: 1.0000 - 70ms/epoch - 35ms/step
# Loss: 0.0002
# Accuracy: 100.0%
