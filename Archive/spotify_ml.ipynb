# %%
# STEP 1: Get Spotify Client Information
import pandas as pd
import time
import numpy as np
from sklearn.neighbors import NearestNeighbors
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib', 'inline')
import numpy as np
import seaborn as sns
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id = '31a78af7c9954c55951a4205935546f5'
client_secret = 'd9b2cb8c10014ce7ba2d8bbd3f9939a6'

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id,
                                                           client_secret=client_secret))

# %%
name = ["Micheal Jackson"]
result = sp.search(name) 
result['tracks']['items'][1]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3fMbdgg4jU18AjLCKBhRSm'},
#   'href': 'https://api.spotify.com/v1/artists/3fMbdgg4jU18AjLCKBhRSm',
#   'id': '3fMbdgg4jU18AjLCKBhRSm',
#   'name': 'Michael Jackson',
#   'type': 'artist',
#   'uri': 'spotify:artist:3fMbdgg4jU18AjLCKBhRSm'}]

# %%
def album_songs(artist):
    name = [artist]
    result = sp.search(name) 
    result['tracks']['items'][1]['artists']
    
#Extract Artist's uri
    artists_uris = results['tracks']['items'][0]['artists'][0]['uri']
#Pull all of the artist's albums
    artist_albums = sp.artist_albums(artists_uris, album_type='album')
#Store artist's albums' names' and uris in separate lists
    artist_album_names = []
    artist_album_uris = []
    for i in range(len(artist_albums['items'])):
        artist_album_names.append(artist_albums['items'][i]['name'])
        artist_album_uris.append(artist_albums['items'][i]['uri'])

    def album_songs(uri):
        album = uri 
        spotify_albums[album] = {}
        #Create keys-values of empty lists inside nested dictionary for album
        spotify_albums[album]['album'] = [] 
        spotify_albums[album]['track_number'] = []
        spotify_albums[album]['id'] = []
        spotify_albums[album]['name'] = []
        spotify_albums[album]['uri'] = []
        #pull data on album tracks
        tracks = sp.album_tracks(album) 
        for n in range(len(tracks['items'])): 
            spotify_albums[album]['album'].append(artist_album_names[album_count]) 
            spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
            spotify_albums[album]['id'].append(tracks['items'][n]['id'])
            spotify_albums[album]['name'].append(tracks['items'][n]['name'])
            spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

    spotify_albums = {}
    album_count = 0
    for i in artist_album_uris: #each album
        album_songs(i)
        print(str(artist_album_names[album_count]) + " album songs has been added to spotify_albums dictionary")
        album_count+=1 #Updates album count once all tracks have been added
    
    def audio_features(album):
        #Add new key-values to store audio features
        spotify_albums[album]['acousticness'] = []
        spotify_albums[album]['danceability'] = []
        spotify_albums[album]['energy'] = []
        spotify_albums[album]['instrumentalness'] = []
        spotify_albums[album]['liveness'] = []
        spotify_albums[album]['loudness'] = []
        spotify_albums[album]['speechiness'] = []
        spotify_albums[album]['tempo'] = []
        spotify_albums[album]['valence'] = []
        spotify_albums[album]['popularity'] = []
    
        track_count = 0
        for track in spotify_albums[album]['uri']:
            #pull audio features per track
            features = sp.audio_features(track)
        
            #Append to relevant key-value
            spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
            spotify_albums[album]['danceability'].append(features[0]['danceability'])
            spotify_albums[album]['energy'].append(features[0]['energy'])
            spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
            spotify_albums[album]['liveness'].append(features[0]['liveness'])
            spotify_albums[album]['loudness'].append(features[0]['loudness'])
            spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
            spotify_albums[album]['tempo'].append(features[0]['tempo'])
            spotify_albums[album]['valence'].append(features[0]['valence'])
            #popularity is stored elsewhere
            pop = sp.track(track)
            spotify_albums[album]['popularity'].append(pop['popularity'])
            track_count+=1    

    sleep_min = 2
    sleep_max = 5
    start_time = time.time()
    request_count = 0
    for i in spotify_albums:
        audio_features(i)
        request_count+=1
        if request_count % 5 == 0:
            print(str(request_count) + " playlists completed")
            time.sleep(np.random.uniform(sleep_min, sleep_max))
            print('Loop #: {}'.format(request_count))
            print('Elapsed Time: {} seconds'.format(time.time() - start_time))
        
    dic_df = {}
    dic_df['album'] = []
    dic_df['track_number'] = []
    dic_df['id'] = []
    dic_df['name'] = []
    dic_df['uri'] = []
    dic_df['acousticness'] = []
    dic_df['danceability'] = []
    dic_df['energy'] = []
    dic_df['instrumentalness'] = []
    dic_df['liveness'] = []
    dic_df['loudness'] = []
    dic_df['speechiness'] = []
    dic_df['tempo'] = []
    dic_df['valence'] = []
    dic_df['popularity'] = []
    for album in spotify_albums: 
        for feature in spotify_albums[album]:
            dic_df[feature].extend(spotify_albums[album][feature])
        
    len(dic_df['album'])

   
    dataframe = pd.DataFrame.from_dict(dic_df)
    return dataframe

# %%
album_songs("Michael Jackson")
# Out:
# Man of the Woods album songs has been added to spotify_albums dictionary
# The Book of Love (Original Motion Picture Soundtrack) album songs has been added to spotify_albums dictionary
# The 20/20 Experience - 2 of 2 (Deluxe) album songs has been added to spotify_albums dictionary
# The 20/20 Experience (Deluxe Version) album songs has been added to spotify_albums dictionary
# 12" Masters - The Essential Mixes album songs has been added to spotify_albums dictionary
# FutureSex/LoveSounds Deluxe Edition album songs has been added to spotify_albums dictionary
# FutureSex/LoveSounds album songs has been added to spotify_albums dictionary
# Justified album songs has been added to spotify_albums dictionary
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 32.65497159957886 seconds
#                 album  track_number                      id  \
# 0    Man of the Woods             1  5ZpjODX6OH1xZs3AOewTO6
# 1    Man of the Woods             2  1KAhsLqLYiqCZ1G8ljKDtB
# 2    Man of the Woods             3  249c7UYQRwLb8tUykq8IwX
# 3    Man of the Woods             4  4KTU5aa5s547f1JF5DImhF
# 4    Man of the Woods             5  7GfhZZq8plOVTeqsDMbftc
# ..                ...           ...                     ...
# 118         Justified             9  547DBSmURHs1EjJlC4zviI
# 119         Justified            10  44FZ6TP6a75s7eU62nHBZ3
# 120         Justified            11  2aO1wo2q6I5WNIT4cqqgDb
# 121         Justified            12  1EEwfP7Trp1E52C40kCWcc
# 122         Justified            13  09N8D0V8rZm1JEOmNYKrKr
#
#                            name                                   uri  \
# 0                        Filthy  spotify:track:5ZpjODX6OH1xZs3AOewTO6
# 1           Midnight Summer Jam  spotify:track:1KAhsLqLYiqCZ1G8ljKDtB
# 2                         Sauce  spotify:track:249c7UYQRwLb8tUykq8IwX
# 3              Man of the Woods  spotify:track:4KTU5aa5s547f1JF5DImhF
# 4                 Higher Higher  spotify:track:7GfhZZq8plOVTeqsDMbftc
# ..                          ...                                   ...
# 118           Still On My Brain  spotify:track:547DBSmURHs1EjJlC4zviI
# 119  (And She Said) Take Me Now  spotify:track:44FZ6TP6a75s7eU62nHBZ3
# 120                Right For Me  spotify:track:2aO1wo2q6I5WNIT4cqqgDb
# 121           Let's Take A Ride  spotify:track:1EEwfP7Trp1E52C40kCWcc
# 122                 Never Again  spotify:track:09N8D0V8rZm1JEOmNYKrKr
#
#      acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0          0.0354         0.745   0.579          0.011800    0.2460    -5.771
# 1          0.1010         0.805   0.759          0.354000    0.1830    -5.198
# 2          0.0598         0.727   0.850          0.000109    0.3120    -4.965
# 3          0.3150         0.624   0.452          0.000010    0.3110    -8.206
# 4          0.1490         0.658   0.620          0.000012    0.1570    -6.634
# ..            ...           ...     ...               ...       ...       ...
# 118        0.4530         0.588   0.409          0.000005    0.0726    -7.507
# 119        0.5560         0.866   0.695          0.000057    0.0906    -5.818
# 120        0.0798         0.832   0.756          0.000111    0.0452    -7.948
# 121        0.1180         0.711   0.653          0.000013    0.0839    -6.484
# 122        0.8310         0.427   0.252          0.000000    0.1030   -11.758
#
#      speechiness    tempo  valence  popularity
# 0         0.1380   97.002    0.645          53
# 1         0.0438  120.057    0.721          42
# 2         0.0401  113.019    0.801          38
# 3         0.0681  199.775    0.724          49
# 4         0.0517   89.955    0.522          45
# ..           ...      ...      ...         ...
# 118       0.0480  130.221    0.262          37
# 119       0.1210  103.895    0.879          35
# 120       0.0748   99.882    0.682          34
# 121       0.0429   90.018    0.748          38
# 122       0.0315   92.551    0.292          37
#
# [123 rows x 15 columns]

# %%
song_df = dataframe.drop(["id","uri","track_number"],axis=1)

# %%
print(song_df['name'].value_counts())
# Out:
# BATHROOM (skit)                                               7
# SAME THING                                                    7
# BOOTY CALL (skit)                                             7
# I WISH                                                        7
# NOT FAIR (feat. Corbin)                                       7
# WRONG (feat. Lil Mosey)                                       7
# TELL ME WHY                                                   7
# MAYBE                                                         7
# NEW GUY (skit)                                                7
# ERASE U                                                       7
# RUNNING                                                       7
# WISH YOU WELL (skit)                                          7
# NEED YOU MOST (So Sick)                                       7
# SELFISH                                                       7
# GO (feat. Juice WRLD)                                         6
# PIKACHU                                                       5
# SO DONE                                                       5
# TRAGIC (feat. Youngboy Never Broke Again & Internet Money)    5
# ALWAYS DO                                                     5
# FEEL SOMETHING (feat. Marshmello)                             5
# WITHOUT YOU                                                   5
# F*CK YOU, GOODBYE (feat. Machine Gun Kelly)                   5
# OVER YOU                                                      3
# NOT SOBER (feat. Polo G & Stunna Gambino)                     3
# STILL CHOSE YOU (feat. Mustard)                               3
# BAD NEWS                                                      3
# DON'T LEAVE ME (feat. G Herbo & Lil Durk)                     3
# SAME ENERGY                                                   3
# STAY (with Justin Bieber)                                     3
# BEST FOR ME                                                   2
# ATTENTION                                                     2
# SITUATION                                                     2
# LONELY AND F*CKED UP                                          2
# ABOUT YOU                                                     2
# I DON'T KNOW                                                  2
# GO                                                            1
# Name: name, dtype: int64

# %%
final_df = song_df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 36

# %%
final_df
# Out:
#                       album  \
# 4    F*CK LOVE 3+: OVER YOU
# 5    F*CK LOVE 3+: OVER YOU
# 7    F*CK LOVE 3+: OVER YOU
# 8    F*CK LOVE 3+: OVER YOU
# 9    F*CK LOVE 3+: OVER YOU
# 10   F*CK LOVE 3+: OVER YOU
# 11   F*CK LOVE 3+: OVER YOU
# 12   F*CK LOVE 3+: OVER YOU
# 32   F*CK LOVE 3+: OVER YOU
# 70    F*CK LOVE 3: OVER YOU
# 71    F*CK LOVE 3: OVER YOU
# 72    F*CK LOVE 3: OVER YOU
# 73    F*CK LOVE 3: OVER YOU
# 76    F*CK LOVE 3: OVER YOU
# 99       F*CK LOVE (SAVAGE)
# 101      F*CK LOVE (SAVAGE)
# 102      F*CK LOVE (SAVAGE)
# 103      F*CK LOVE (SAVAGE)
# 104      F*CK LOVE (SAVAGE)
# 105      F*CK LOVE (SAVAGE)
# 106      F*CK LOVE (SAVAGE)
# 111      F*CK LOVE (SAVAGE)
# 115      F*CK LOVE (SAVAGE)
# 122      F*CK LOVE (SAVAGE)
# 144               F*CK LOVE
# 145               F*CK LOVE
# 146               F*CK LOVE
# 147               F*CK LOVE
# 149               F*CK LOVE
# 150               F*CK LOVE
# 151               F*CK LOVE
# 153               F*CK LOVE
# 154               F*CK LOVE
# 156               F*CK LOVE
# 157               F*CK LOVE
# 164               F*CK LOVE
#
#                                                   name  acousticness  \
# 4            DON'T LEAVE ME (feat. G Herbo & Lil Durk)       0.09170
# 5                                             BAD NEWS       0.07100
# 7                                         I DON'T KNOW       0.03190
# 8                                            ABOUT YOU       0.01160
# 9                                 LONELY AND F*CKED UP       0.04210
# 10                                           SITUATION       0.05510
# 11                                           ATTENTION       0.02740
# 12                                         BEST FOR ME       0.55300
# 32                                WISH YOU WELL (skit)       0.95500
# 70                                            OVER YOU       0.43100
# 71           NOT SOBER (feat. Polo G & Stunna Gambino)       0.09280
# 72                           STAY (with Justin Bieber)       0.03830
# 73                                         SAME ENERGY       0.13500
# 76                     STILL CHOSE YOU (feat. Mustard)       0.41000
# 99                                             PIKACHU       0.06620
# 101  TRAGIC (feat. Youngboy Never Broke Again & Int...       0.03830
# 102                                          ALWAYS DO       0.04420
# 103                  FEEL SOMETHING (feat. Marshmello)       0.05900
# 104        F*CK YOU, GOODBYE (feat. Machine Gun Kelly)       0.06930
# 105                                        WITHOUT YOU       0.21300
# 106                                  BOOTY CALL (skit)       0.97800
# 111                                    BATHROOM (skit)       0.94000
# 115                                     NEW GUY (skit)       0.97700
# 122                                            SO DONE       0.23200
# 144                                              MAYBE       0.00554
# 145                            WRONG (feat. Lil Mosey)       0.03800
# 146                                             I WISH       0.03750
# 147                            NOT FAIR (feat. Corbin)       0.46800
# 149                              GO (feat. Juice WRLD)       0.15700
# 150                                        TELL ME WHY       0.10900
# 151                                         SAME THING       0.02250
# 153                                            ERASE U       0.04580
# 154                                            RUNNING       0.37700
# 156                            NEED YOU MOST (So Sick)       0.06810
# 157                                            SELFISH       0.16600
# 164                                                 GO       0.16300
#
#      danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 4           0.639   0.727          0.000000    0.1110    -5.230       0.0901
# 5           0.550   0.533          0.000000    0.1200    -6.853       0.0441
# 7           0.530   0.673          0.000000    0.1480    -6.851       0.0584
# 8           0.632   0.508          0.000000    0.0992    -8.435       0.0842
# 9           0.752   0.631          0.000000    0.1880    -6.809       0.0495
# 10          0.754   0.836          0.000000    0.2650    -5.991       0.2900
# 11          0.878   0.583          0.000000    0.3930    -7.053       0.0729
# 12          0.536   0.482          0.000000    0.1230    -6.749       0.0311
# 32          0.619   0.256          0.000000    0.5960   -12.522       0.5380
# 70          0.454   0.718          0.000000    0.1630    -5.084       0.1070
# 71          0.671   0.639          0.000000    0.0941    -6.852       0.1340
# 72          0.591   0.764          0.000000    0.1030    -5.484       0.0483
# 73          0.676   0.494          0.000000    0.0995    -7.077       0.2610
# 76          0.724   0.500          0.000000    0.1150    -7.112       0.2590
# 99          0.747   0.487          0.000000    0.3600    -7.064       0.1250
# 101         0.779   0.642          0.000000    0.2000    -6.321       0.1160
# 102         0.762   0.426          0.000000    0.0858    -6.865       0.1130
# 103         0.523   0.609          0.000000    0.1400    -7.802       0.1910
# 104         0.721   0.632          0.000000    0.2910    -6.695       0.0358
# 105         0.662   0.413          0.000000    0.1340    -7.357       0.0299
# 106         0.773   0.398          0.000000    0.4130   -11.494       0.8710
# 111         0.800   0.743          0.000000    0.7740    -9.050       0.9120
# 115         0.766   0.363          0.000009    0.5750   -12.350       0.9490
# 122         0.719   0.598          0.000000    0.1150    -6.254       0.0770
# 144         0.606   0.532          0.000000    0.2920    -4.833       0.0777
# 145         0.389   0.768          0.000000    0.1190    -4.765       0.2560
# 146         0.788   0.656          0.000000    0.1270    -6.974       0.0470
# 147         0.412   0.657          0.000000    0.3180    -5.535       0.1240
# 149         0.487   0.740          0.000000    0.6120    -4.973       0.0944
# 150         0.600   0.723          0.000000    0.1670    -4.928       0.1580
# 151         0.662   0.659          0.000000    0.1070    -4.642       0.1550
# 153         0.750   0.641          0.000000    0.1930    -5.134       0.0353
# 154         0.438   0.585          0.000000    0.1300    -5.425       0.0908
# 156         0.630   0.707          0.000000    0.2840    -3.632       0.0508
# 157         0.373   0.539          0.000000    0.1390    -4.865       0.0860
# 164         0.606   0.737          0.000000    0.6070    -5.075       0.0985
#
#        tempo  valence  popularity
# 4     75.992   0.2560          48
# 5     87.480   0.1710          51
# 7    160.886   0.4060          56
# 8    163.985   0.0647          56
# 9    124.983   0.5020          59
# 10    76.528   0.2440          53
# 11   132.939   0.3200          55
# 12    90.966   0.1850          60
# 32   170.572   0.6560          42
# 70   141.556   0.2750          59
# 71   119.820   0.3850          72
# 72   169.928   0.4780          87
# 73   169.685   0.7560          61
# 76    97.694   0.3170          65
# 99    92.978   0.2480          59
# 101   82.363   0.3880          71
# 102  167.827   0.5820          71
# 103  154.051   0.3740          67
# 104   92.057   0.2960          72
# 105   93.005   0.4670          79
# 106   56.284   0.5560          44
# 111  116.899   0.5930           5
# 115   85.494   0.0529           3
# 122  142.592   0.3030          66
# 144   89.079   0.1560          62
# 145   90.146   0.3340          67
# 146  138.981   0.5490          53
# 147   76.342   0.6250          60
# 149   73.779   0.5220          74
# 150  149.881   0.4630          66
# 151  135.950   0.3630          52
# 153  144.988   0.7430          56
# 154  100.834   0.3130          53
# 156   86.849   0.2850          64
# 157   77.006   0.0750          62
# 164   73.975   0.4890          40

# %%
song_df.to_csv("spotify_music.csv")
