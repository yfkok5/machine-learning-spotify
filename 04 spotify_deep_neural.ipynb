# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in data
data = Path("Resources/spotify_raw_data.csv")
df = pd.read_csv(data)
df.head(10)
# Out:
#    Unnamed: 0       artist                      track  danceability  energy  \
# 0           0   Jonas Blue            Mama - Acoustic         0.564   0.364
# 1           1     Jooyoung                Same as you         0.701   0.519
# 2           2    Nightwish  The Poet And The Pendulum         0.309   0.740
# 3           3   Ed Sheeran                 Afire Love         0.552   0.637
# 4           4  Linkin Park                   Given Up         0.655   0.885
# 5           5     He Is We               All About Us         0.564   0.534
# 6           6   Ed Sheeran               Take It Back         0.754   0.613
# 7           7      Defqwop                Heart Afire         0.414   0.708
# 8           8    SEVENTEEN                     Mansae         0.749   0.955
# 9           9    Nightwish            End Of All Hope         0.477   0.946
#
#    key  loudness  mode  speechiness  acousticness  ...  valence    tempo  \
# 0   10    -5.845     0       0.0631      0.759000  ...    0.591   86.538
# 1    1    -6.382     1       0.0516      0.314000  ...    0.498   89.977
# 2    7    -5.917     0       0.0456      0.008540  ...    0.166  144.861
# 3    5    -6.568     1       0.0445      0.464000  ...    0.333   97.970
# 4    7    -4.116     1       0.0438      0.001170  ...    0.938  100.088
# 5    4    -6.050     1       0.0238      0.280000  ...    0.409   85.964
# 6    5    -6.342     1       0.2290      0.318000  ...    0.904  113.196
# 7    0    -4.181     0       0.0912      0.031600  ...    0.392  199.900
# 8    7    -1.767     1       0.0867      0.054700  ...    0.761  111.960
# 9    5    -6.734     1       0.0423      0.000061  ...    0.563   79.948
#
#              type                      id  \
# 0  audio_features  3VOtM6x5KXZuxSzHaaf9oO
# 1  audio_features  0wpskpgrWHEDWjPgkddspN
# 2  audio_features  2XD4JzbZWRuRKzzCi5Cocm
# 3  audio_features  12B0Twa9kRz45Xw2PgXHJm
# 4  audio_features  1fLlRApgzxWweF1JTf8yM5
# 5  audio_features  2185NMvk68x92ygV1iP89F
# 6  audio_features  2dmOWlEHrP266Qgz6wnUrd
# 7  audio_features  0JQjr0kpluPAuskMPHjqh3
# 8  audio_features  5rIsrawNyPv1q8v11iwJsh
# 9  audio_features  3vm2YWzVKrIaWXZcmEIFdP
#
#                                     uri  \
# 0  spotify:track:3VOtM6x5KXZuxSzHaaf9oO
# 1  spotify:track:0wpskpgrWHEDWjPgkddspN
# 2  spotify:track:2XD4JzbZWRuRKzzCi5Cocm
# 3  spotify:track:12B0Twa9kRz45Xw2PgXHJm
# 4  spotify:track:1fLlRApgzxWweF1JTf8yM5
# 5  spotify:track:2185NMvk68x92ygV1iP89F
# 6  spotify:track:2dmOWlEHrP266Qgz6wnUrd
# 7  spotify:track:0JQjr0kpluPAuskMPHjqh3
# 8  spotify:track:5rIsrawNyPv1q8v11iwJsh
# 9  spotify:track:3vm2YWzVKrIaWXZcmEIFdP
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3VOtM6x5KXZu...
# 1  https://api.spotify.com/v1/tracks/0wpskpgrWHED...
# 2  https://api.spotify.com/v1/tracks/2XD4JzbZWRuR...
# 3  https://api.spotify.com/v1/tracks/12B0Twa9kRz4...
# 4  https://api.spotify.com/v1/tracks/1fLlRApgzxWw...
# 5  https://api.spotify.com/v1/tracks/2185NMvk68x9...
# 6  https://api.spotify.com/v1/tracks/2dmOWlEHrP26...
# 7  https://api.spotify.com/v1/tracks/0JQjr0kpluPA...
# 8  https://api.spotify.com/v1/tracks/5rIsrawNyPv1...
# 9  https://api.spotify.com/v1/tracks/3vm2YWzVKrIa...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3VOt...      192277
# 1  https://api.spotify.com/v1/audio-analysis/0wps...      223044
# 2  https://api.spotify.com/v1/audio-analysis/2XD4...      834720
# 3  https://api.spotify.com/v1/audio-analysis/12B0...      314280
# 4  https://api.spotify.com/v1/audio-analysis/1fLl...      189293
# 5  https://api.spotify.com/v1/audio-analysis/2185...      206533
# 6  https://api.spotify.com/v1/audio-analysis/2dmO...      208400
# 7  https://api.spotify.com/v1/audio-analysis/0JQj...      240039
# 8  https://api.spotify.com/v1/audio-analysis/5rIs...      186875
# 9  https://api.spotify.com/v1/audio-analysis/3vm2...      233800
#
#   time_signature  target
# 0              4       1
# 1              4       1
# 2              4       1
# 3              4       1
# 4              4       1
# 5              4       1
# 6              4       1
# 7              4       1
# 8              4       1
# 9              4       1
#
# [10 rows x 22 columns]

# %%
#identify column headings
df.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'track', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature', 'target'],
#       dtype='object')

# %%
df["target"].value_counts()
# Out:
# 0    90
# 1    20
# Name: target, dtype: int64

# %%
#drop unnecessary columns
raw_data = df.drop(['Unnamed: 0',"artist","track","type","id","uri","track_href","analysis_url","time_signature"],axis=1)
raw_data.head(20)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.564   0.364   10    -5.845     0       0.0631      0.759000
# 1          0.701   0.519    1    -6.382     1       0.0516      0.314000
# 2          0.309   0.740    7    -5.917     0       0.0456      0.008540
# 3          0.552   0.637    5    -6.568     1       0.0445      0.464000
# 4          0.655   0.885    7    -4.116     1       0.0438      0.001170
# 5          0.564   0.534    4    -6.050     1       0.0238      0.280000
# 6          0.754   0.613    5    -6.342     1       0.2290      0.318000
# 7          0.414   0.708    0    -4.181     0       0.0912      0.031600
# 8          0.749   0.955    7    -1.767     1       0.0867      0.054700
# 9          0.477   0.946    5    -6.734     1       0.0423      0.000061
# 10         0.493   0.865    7    -4.710     0       0.0357      0.286000
# 11         0.667   0.361    1    -8.690     0       0.0273      0.575000
# 12         0.592   0.842    1    -6.421     0       0.1100      0.066100
# 13         0.624   0.857    0    -4.444     1       0.0585      0.001850
# 14         0.380   0.438    5    -5.526     0       0.0962      0.025900
# 15         0.628   0.485    0    -6.020     1       0.0733      0.010100
# 16         0.439   0.951    3    -3.690     1       0.0569      0.001160
# 17         0.394   0.971    2    -3.104     0       0.0588      0.001150
# 18         0.502   0.954    5    -3.860     0       0.1110      0.022300
# 19         0.341   0.867    7    -4.727     0       0.0492      0.293000
#
#     instrumentalness  liveness  valence    tempo  duration_ms  target
# 0           0.000000    0.0839    0.591   86.538       192277       1
# 1           0.000000    0.2070    0.498   89.977       223044       1
# 2           0.025800    0.1190    0.166  144.861       834720       1
# 3           0.000016    0.1360    0.333   97.970       314280       1
# 4           0.000473    0.0448    0.938  100.088       189293       1
# 5           0.000000    0.1210    0.409   85.964       206533       1
# 6           0.000000    0.3350    0.904  113.196       208400       1
# 7           0.000000    0.0623    0.392  199.900       240039       1
# 8           0.000000    0.1120    0.761  111.960       186875       1
# 9           0.027100    0.3330    0.563   79.948       233800       1
# 10          0.000000    0.1520    0.192   90.979       242440       1
# 11          0.005060    0.0805    0.290  134.018       242000       1
# 12          0.000000    0.3130    0.708  121.077       216756       1
# 13          0.003580    0.2450    0.435  104.977       200880       1
# 14          0.000013    0.1540    0.349  179.404       203813       1
# 15          0.000004    0.1130    0.540  119.879       237560       1
# 16          0.899000    0.0926    0.247   99.533       280547       1
# 17          0.540000    0.1650    0.335  138.702       235867       1
# 18          0.000186    0.1350    0.199  126.934       335680       1
# 19          0.000000    0.2570    0.200  182.023       240440       1

# %%
# Define the features X set and the target y vector
X = raw_data.drop("target",axis=1)
y = raw_data.loc[:, ["target"]]

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=5)

# Scale the data of the features set using the StandardScaler
X_scaler = StandardScaler()
X_scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((82, 12), (28, 12), (82, 1), (28, 1))

# %%
# Define the model - shallow neural network
model = Sequential()

# Add the first layer where the input dimensions 11 columns of the training data
model.add(Dense(50, activation='relu', input_dim=X_train_scaled.shape[1]))

model.add(Dense(50, activation='relu', input_dim=50))

model.add(Dense(1, activation='sigmoid',input_dim=50))

# %%
# The output layer has either 0 or 1
y_train.target.value_counts()
number_outputs = 1

# %%
# Compile the model using categorical_crossentropy for the loss function, the adam optimizer,
# and add accuracy to the training metrics
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
# Use the training data to fit (train) the model
# @NOTE: Experiment with the number of training epochs to find the minimum iterations required to achieve a good accuracy
model.fit(
    X_train_scaled,
    y_train,
    epochs=30,
    shuffle=True,
    verbose=1
)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7209 - accuracy: 0.4268
# Epoch 2/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.6696 - accuracy: 0.6341
# Epoch 3/30
# 3/3 [==============================] - 0s 1000us/step - loss: 0.6295 - accuracy: 0.7805
# Epoch 4/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.5955 - accuracy: 0.7927
# Epoch 5/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.5698 - accuracy: 0.7927
# Epoch 6/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.5450 - accuracy: 0.7927
# Epoch 7/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5257 - accuracy: 0.7927
# Epoch 8/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.5091 - accuracy: 0.7927
# Epoch 9/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4945 - accuracy: 0.7927
# Epoch 10/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4817 - accuracy: 0.7927
# Epoch 11/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.4698 - accuracy: 0.7927
# Epoch 12/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.7927
# Epoch 13/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.4479 - accuracy: 0.7927
# Epoch 14/30
# 3/3 [==============================] - 0s 1000us/step - loss: 0.4373 - accuracy: 0.7927
# Epoch 15/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.4274 - accuracy: 0.7927
# Epoch 16/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.4172 - accuracy: 0.7927
# Epoch 17/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.8049
# Epoch 18/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8049
# Epoch 19/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.3887 - accuracy: 0.8049
# Epoch 20/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.8049
# Epoch 21/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8049
# Epoch 22/30
# 3/3 [==============================] - 0s 501us/step - loss: 0.3619 - accuracy: 0.8171
# Epoch 23/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3537 - accuracy: 0.8171
# Epoch 24/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3452 - accuracy: 0.8171
# Epoch 25/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.3374 - accuracy: 0.8171
# Epoch 26/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3294 - accuracy: 0.8293
# Epoch 27/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3207 - accuracy: 0.8293
# Epoch 28/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3128 - accuracy: 0.8293
# Epoch 29/30
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.8293
# Epoch 30/30
# 3/3 [==============================] - 0s 500us/step - loss: 0.2971 - accuracy: 0.8293

# %%
# Evaluate the model using the testing data
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1/1 - 0s - loss: 0.3841 - accuracy: 0.8929 - 57ms/epoch - 57ms/step
# Normal Neural Network - Loss: 0.38409915566444397, Accuracy: 0.8928571343421936

# %%
# Make some predictions with the loaded model
predicted = model.predict(X_test_scaled)
predicted
# Out:
# array([[0.18031481],
#        [0.2333177 ],
#        [0.38771653],
#        [0.2152498 ],
#        [0.18843329],
#        [0.504023  ],
#        [0.02307132],
#        [0.32215765],
#        [0.14775532],
#        [0.26278532],
#        [0.28118908],
#        [0.05454969],
#        [0.21796563],
#        [0.05034882],
#        [0.37712577],
#        [0.5963055 ],
#        [0.09264243],
#        [0.21780673],
#        [0.17606002],
#        [0.26519156],
#        [0.00116628],
#        [0.155541  ],
#        [0.10513139],
#        [0.01459318],
#        [0.2515124 ],
#        [0.2490592 ],
#        [0.08747789],
#        [0.14873365]], dtype=float32)

# %%
y_test.index
# Out:
# Int64Index([ 87,  10,  20,  23,  63,  54,  42,  56,  28,  66,  69,  72,  74,
#               6,  40,  17,  59,  50,  81, 103,  48,  39,  22,  35,  46,  89,
#              88,  95],
#            dtype='int64')

# %%
predicted = enc.inverse_transform(predicted).flatten().tolist()

results = pd.DataFrame({
    "Index": y_test.index.values,
    "Actual": y_test.target.values,
    "Predicted": predicted
})

results.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15384/3043125072.py in <module>
# ----> 1 predicted = enc.inverse_transform(predicted).flatten().tolist()
#       2
#       3 results = pd.DataFrame({
#       4     "Index": y_test.index.values,
#       5     "Actual": y_test.target.values,
#
# NameError: name 'enc' is not defined

# %%
# Print the Classification Report
from sklearn.metrics import classification_report
print(classification_report(results.Actual, results.Predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98        25
#            1       1.00      0.67      0.80         3
#
#     accuracy                           0.96        28
#    macro avg       0.98      0.83      0.89        28
# weighted avg       0.97      0.96      0.96        28
