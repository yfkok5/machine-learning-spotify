# %% [markdown]
# # Neural Network Spotify Playlist

# %% [markdown]
# ### Data Pre-Processing
#
# Prepare the data for the neural network. This includes splitting the data into a training and testing dataset, Scaling the data, and encoding the categorical target values

# %%
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import panel as pn
pn.extension('plotly')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf

# %%
#reading into compiled csv
data = Path("Resources/spotify_main_raw_data.csv")
df = pd.read_csv(data)
df.shape
df.columns
# Out:
# Index(['Unnamed: 0', 'artist', 'track', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature', 'playlist'],
#       dtype='object')

# %%
#dropping irrelevant columns
raw_data = df.drop(['Unnamed: 0',"track","type","id","uri","track_href","analysis_url","time_signature","artist"],axis=1)
raw_data
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.432  0.0951    1   -23.511     1       0.0388      0.909000
# 1            0.643  0.2800   10   -13.774     1       0.0332      0.965000
# 2            0.322  0.1520    8   -16.765     1       0.0388      0.958000
# 3            0.609  0.1620    3   -17.650     1       0.0375      0.917000
# 4            0.509  0.1540    1   -18.927     1       0.0410      0.978000
# ...            ...     ...  ...       ...   ...          ...           ...
# 1077         0.805  0.9090    0    -6.539     0       0.0505      0.006570
# 1078         0.665  0.5350    9   -15.905     0       0.0718      0.717000
# 1079         0.791  0.6530   11    -7.117     0       0.0316      0.107000
# 1080         0.879  0.3250    9   -12.705     0       0.1380      0.000304
# 1081         0.703  0.8380    2   -13.117     1       0.0406      0.044900
#
#       instrumentalness  liveness  valence    tempo  duration_ms playlist
# 0             0.890000    0.1170   0.0930  100.265       373840     Jazz
# 1             0.867000    0.1070   0.0865  108.046       203097     Jazz
# 2             0.899000    0.1270   0.2030  177.730       207206     Jazz
# 3             0.791000    0.1120   0.1230  106.051       237679     Jazz
# 4             0.936000    0.1150   0.2410  121.049       197273     Jazz
# ...                ...       ...      ...      ...          ...      ...
# 1077          0.926000    0.0674   0.6350  122.004       536046    House
# 1078          0.911000    0.0978   0.1740  119.999       328000    House
# 1079          0.000061    0.1060   0.5550  123.992       219000    House
# 1080          0.923000    0.0877   0.7660  123.023       359794    House
# 1081          0.923000    0.1050   0.0939  120.007       364227    House
#
# [1082 rows x 13 columns]

# %%
#checking correlation between each audio features & song's genre

energy_plot = sns.catplot(x="energy", y="playlist", kind="box", data=raw_data)
loudness_plot = sns.catplot(x="loudness", y="playlist", kind="box", data=raw_data)
dance_plot = sns.catplot(x="danceability", y="playlist", kind="box", data=raw_data)
tempo_plot = sns.catplot(x="tempo", y="playlist", kind="box", data=raw_data)

# %% [markdown]
# # Initialize PCA model
# pca = PCA(n_components=8)
#
# Get 8 principal components for the data.
# spotify_pca = pca.fit_transform(spotify_scaled)
#
# df_spotify_pca = pd.DataFrame(
#     data=spotify_pca, columns=["principal component 1",
#                                "principal component 2",
#                                "principal component 3",
#                                "principal component 4",
#                                "principal component 5",
#                                "principal component 6",
#                                "principal component 7",
#                                "principal component 8"]
#                                                         )
# #df_spotify_pca.head()

# %%
#Verifying playlist classifications
raw_data.playlist.value_counts()
# Out:
# RNB      390
# House    358
# Jazz     334
# Name: playlist, dtype: int64

# %%
# Define the features X set and the target y vector
X = raw_data.drop("playlist",axis=1)
y = raw_data.loc[:, ["playlist"]]

# %%
# Split the dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# Acknowledge the dimension of both test and training data
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((811, 12), (271, 12), (811, 1), (271, 1))

# %%
# Scale the training and testing input features using StandardScaler
X_scaler = StandardScaler()
X_scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Apply One-hot encoding to the target labels
enc = OneHotEncoder()
enc.fit(y_train)

encoded_y_train = enc.transform(y_train).toarray()
encoded_y_test = enc.transform(y_test).toarray()
encoded_y_train[0]
# Out:
# array([0., 1., 0.])

# %% [markdown]
# # Build a Deep Neural Network

# %%
# Create a sequential model
model = Sequential()

# %%
# Add the first layer where the input dimensions are the X.shape[1] = 8 columns of the training data
model.add(Dense(100, activation='relu', input_dim = X.shape[1]))
    
# Add the 2nd layer where the input dimensions are the 12 columns of the training data
model.add(Dense(100, activation='relu', input_dim = 100))

# Add output layer (3 outputs = Rock, Jazz & RNB)
model.add(Dense(3, activation="softmax", input_dim = 100))

# %%
# The output layer has 8 columns that are one-hot encoded
y_train.playlist.value_counts()

# 5 output since there're 5 playlists
number_outputs = 3

# %%
# Compile the model using categorical_crossentropy for the loss function, the adam optimizer,
# and add accuracy to the training metrics
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               1300
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 11,703
# Trainable params: 11,703
# Non-trainable params: 0
# _________________________________________________________________

# %%
#We call fit(), which will train the model by slicing the data into "batches" of size batch_size, 
#and repeatedly iterating over the entire dataset for a given number of epochs.

# Identifying data dimension
X_train.shape, y_train.shape
# Out:
# ((811, 12), (811, 1))

# %%
#using 10% of training data as validation data
round(-X_train.shape[0]*0.1)
# Out:
# -81

# %%
#ADD VALIDATION DATA
#https://www.tensorflow.org/guide/keras/train_and_evaluate
x_val = X_train_scaled[round(-X_train.shape[0]*0.1):]
y_val = encoded_y_train[round(-X_train.shape[0]*0.1):]
x_train = X_train_scaled[:round(-X_train.shape[0]*0.1)]
y_train = encoded_y_train[:round(-X_train.shape[0]*0.1)]

epochs = 60

print("Fit model on training data")
history = model.fit(
    X_train_scaled,
    encoded_y_train,
    batch_size=64,
    epochs=epochs,
    # We pass some validation for
    # monitoring validation loss and metrics
    # at the end of each epoch
    validation_data=(x_val, y_val),
)
# Out:
# Fit model on training data
# Epoch 1/60
# 13/13 [==============================] - 0s 8ms/step - loss: 0.9372 - accuracy: 0.6005 - val_loss: 0.7770 - val_accuracy: 0.7160
# Epoch 2/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.7208 - accuracy: 0.7374 - val_loss: 0.6461 - val_accuracy: 0.7654
# Epoch 3/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.6163 - accuracy: 0.7645 - val_loss: 0.5713 - val_accuracy: 0.7778
# Epoch 4/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5481 - accuracy: 0.7916 - val_loss: 0.5286 - val_accuracy: 0.7901
# Epoch 5/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.8138 - val_loss: 0.4920 - val_accuracy: 0.8148
# Epoch 6/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4671 - accuracy: 0.8311 - val_loss: 0.4725 - val_accuracy: 0.7901
# Epoch 7/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.8360 - val_loss: 0.4511 - val_accuracy: 0.8148
# Epoch 8/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.4169 - accuracy: 0.8459 - val_loss: 0.4380 - val_accuracy: 0.8272
# Epoch 9/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 0.8533 - val_loss: 0.4221 - val_accuracy: 0.8395
# Epoch 10/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8582 - val_loss: 0.4103 - val_accuracy: 0.8272
# Epoch 11/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8656 - val_loss: 0.3898 - val_accuracy: 0.8765
# Epoch 12/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8718 - val_loss: 0.3809 - val_accuracy: 0.8765
# Epoch 13/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8755 - val_loss: 0.3675 - val_accuracy: 0.8765
# Epoch 14/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3321 - accuracy: 0.8755 - val_loss: 0.3576 - val_accuracy: 0.8642
# Epoch 15/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3208 - accuracy: 0.8903 - val_loss: 0.3442 - val_accuracy: 0.8889
# Epoch 16/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.3095 - accuracy: 0.8890 - val_loss: 0.3318 - val_accuracy: 0.8889
# Epoch 17/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2992 - accuracy: 0.8903 - val_loss: 0.3233 - val_accuracy: 0.9136
# Epoch 18/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2923 - accuracy: 0.8940 - val_loss: 0.3186 - val_accuracy: 0.9136
# Epoch 19/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2836 - accuracy: 0.9014 - val_loss: 0.3015 - val_accuracy: 0.9012
# Epoch 20/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2748 - accuracy: 0.9014 - val_loss: 0.2933 - val_accuracy: 0.9136
# Epoch 21/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2690 - accuracy: 0.9063 - val_loss: 0.2886 - val_accuracy: 0.8765
# Epoch 22/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2629 - accuracy: 0.9075 - val_loss: 0.2869 - val_accuracy: 0.9136
# Epoch 23/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9051 - val_loss: 0.2729 - val_accuracy: 0.9136
# Epoch 24/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2493 - accuracy: 0.9186 - val_loss: 0.2652 - val_accuracy: 0.9136
# Epoch 25/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2402 - accuracy: 0.9223 - val_loss: 0.2528 - val_accuracy: 0.9383
# Epoch 26/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.9260 - val_loss: 0.2443 - val_accuracy: 0.9259
# Epoch 27/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2262 - accuracy: 0.9260 - val_loss: 0.2451 - val_accuracy: 0.9259
# Epoch 28/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2193 - accuracy: 0.9322 - val_loss: 0.2401 - val_accuracy: 0.9383
# Epoch 29/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2142 - accuracy: 0.9273 - val_loss: 0.2302 - val_accuracy: 0.9136
# Epoch 30/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2104 - accuracy: 0.9322 - val_loss: 0.2228 - val_accuracy: 0.9383
# Epoch 31/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.2039 - accuracy: 0.9359 - val_loss: 0.2205 - val_accuracy: 0.9383
# Epoch 32/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.9433 - val_loss: 0.2113 - val_accuracy: 0.9506
# Epoch 33/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1901 - accuracy: 0.9396 - val_loss: 0.2083 - val_accuracy: 0.9259
# Epoch 34/60
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.9482 - val_loss: 0.2031 - val_accuracy: 0.9506
# Epoch 35/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1813 - accuracy: 0.9470 - val_loss: 0.1973 - val_accuracy: 0.9630
# Epoch 36/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1765 - accuracy: 0.9445 - val_loss: 0.1921 - val_accuracy: 0.9753
# Epoch 37/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1707 - accuracy: 0.9507 - val_loss: 0.1832 - val_accuracy: 0.9630
# Epoch 38/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1665 - accuracy: 0.9507 - val_loss: 0.1877 - val_accuracy: 0.9630
# Epoch 39/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1668 - accuracy: 0.9519 - val_loss: 0.1868 - val_accuracy: 0.9383
# Epoch 40/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1622 - accuracy: 0.9605 - val_loss: 0.1759 - val_accuracy: 0.9753
# Epoch 41/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1524 - accuracy: 0.9630 - val_loss: 0.1640 - val_accuracy: 0.9753
# Epoch 42/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1499 - accuracy: 0.9642 - val_loss: 0.1688 - val_accuracy: 0.9753
# Epoch 43/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9667 - val_loss: 0.1542 - val_accuracy: 0.9753
# Epoch 44/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1408 - accuracy: 0.9667 - val_loss: 0.1539 - val_accuracy: 0.9753
# Epoch 45/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1371 - accuracy: 0.9679 - val_loss: 0.1508 - val_accuracy: 0.9753
# Epoch 46/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.9642 - val_loss: 0.1466 - val_accuracy: 0.9630
# Epoch 47/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1315 - accuracy: 0.9667 - val_loss: 0.1396 - val_accuracy: 0.9753
# Epoch 48/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.9716 - val_loss: 0.1429 - val_accuracy: 0.9753
# Epoch 49/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 0.9716 - val_loss: 0.1336 - val_accuracy: 0.9753
# Epoch 50/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9729 - val_loss: 0.1290 - val_accuracy: 0.9753
# Epoch 51/60
# 13/13 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9753 - val_loss: 0.1308 - val_accuracy: 0.9753
# Epoch 52/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9766 - val_loss: 0.1242 - val_accuracy: 0.9877
# Epoch 53/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.9741 - val_loss: 0.1207 - val_accuracy: 0.9753
# Epoch 54/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9741 - val_loss: 0.1168 - val_accuracy: 0.9753
# Epoch 55/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9827 - val_loss: 0.1117 - val_accuracy: 0.9753
# Epoch 56/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9766 - val_loss: 0.1041 - val_accuracy: 0.9877
# Epoch 57/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0958 - accuracy: 0.9815 - val_loss: 0.1071 - val_accuracy: 0.9753
# Epoch 58/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.9766 - val_loss: 0.1074 - val_accuracy: 0.9753
# Epoch 59/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9815 - val_loss: 0.0976 - val_accuracy: 0.9753
# Epoch 60/60
# 13/13 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9815 - val_loss: 0.0948 - val_accuracy: 0.9877

# %%
print("Calculating the accuracy")
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
print("Calculating the loss")
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

print("The results are being visualized")
plt.figure(figsize=(15, 15))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)

plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # Evaluate the Model on Test Data

# %%
# Evaluate the model using the testing data
model_loss, model_accuracy = model.evaluate(X_test_scaled, encoded_y_test, verbose=2)
print(f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 9/9 - 0s - loss: 0.5881 - accuracy: 0.8339 - 15ms/epoch - 2ms/step
# Normal Neural Network - Loss: 0.588138997554779, Accuracy: 0.8339483141899109

# %%
y_index = y_test.index.values

y_tracks = []

#to identify which track has been selected for y_test
for index in y_index:
    track = df.at[index, "track"]
    y_tracks.append(track)

# %%
# Make predictions
predicted = model.predict(X_test_scaled)
predicted = enc.inverse_transform(predicted).flatten().tolist()

# creating a prediction table
results = pd.DataFrame({
    "Index": y_test.index.values,
    "Track": y_tracks,
    "Actual": y_test.playlist.values,
    "Predicted": predicted
})
results.head(10)
# Out:
#    Index                               Track Actual Predicted
# 0    776                      Out of My Head  House     House
# 1    699                    Les mots d'amour    RNB       RNB
# 2    719                      Tous mes rêves    RNB       RNB
# 3    805                             No More  House     House
# 4    135                          My Romance   Jazz      Jazz
# 5     99                   You're Good to Me   Jazz      Jazz
# 6     49                  The More I See You   Jazz      Jazz
# 7    481                          All I Need    RNB      Jazz
# 8    913  Tear Me Down (feat. Philip Rustad)  House       RNB
# 9    836                              Regret  House     House

# %%
# Print the Classification Report
from sklearn.metrics import classification_report
print(classification_report(results.Actual, results.Predicted))
# Out:
#               precision    recall  f1-score   support
#
#        House       0.89      0.89      0.89        82
#         Jazz       0.86      0.75      0.80        92
#          RNB       0.77      0.87      0.82        97
#
#     accuracy                           0.83       271
#    macro avg       0.84      0.84      0.84       271
# weighted avg       0.84      0.83      0.83       271
